# %%
from meteostat import Stations
from datetime import datetime
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from meteostat import Stations
#       2 from datetime import datetime
#
# ModuleNotFoundError: No module named 'meteostat'

# %%
# Italy
stations = Stations()
stations = stations.nearby(41.8967, 12.4822)
stations = stations.inventory('hourly', datetime(2016, 1, 1))
station = stations.fetch(5)
print(station)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Italy
# ----> 2 stations = Stations()
#       3 stations = stations.nearby(41.8967, 12.4822)
#       4 stations = stations.inventory('hourly', datetime(2016, 1, 1))
#
# NameError: name 'Stations' is not defined

# %%
# Spain 
stations = Stations()
stations = stations.nearby(40.4167, 3.7033)
stations = stations.inventory('hourly', datetime(2016, 1, 1))
station = stations.fetch(5)
print(station)

# %%
# France
stations = Stations()
stations = stations.nearby(48.8575, 2.3514)
stations = stations.inventory('hourly', datetime(2016, 1, 1))
station = stations.fetch(5)
print(station)

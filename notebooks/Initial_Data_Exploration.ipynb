# %%
import pandas as pd

# %% [markdown]
# ## France Exploration Data

# %%
df = pd.read_csv("/workspace/Renewable-Energy-Prediction/data/raw/France_Power_Generation.csv")

# %%
# Basic information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67831 entries, 0 to 67830
# Data columns (total 25 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Area                                                       67831 non-null  object
#  1   MTU                                                        67831 non-null  object
#  2   DATETIME                                                   67831 non-null  object
#  3   YEAR                                                       67831 non-null  int64
#  4   Biomass  - Actual Aggregated [MW]                          67751 non-null  float64
#  5   Fossil Brown coal/Lignite  - Actual Aggregated [MW]        67823 non-null  object
#  6   Fossil Coal-derived gas  - Actual Aggregated [MW]          67823 non-null  object
# ...

# %%
# Display the first few rows to understand the structure
print(df.head())
# Out:
#           Area                                             MTU  \
# 0  France (FR)  01.01.2015 00:00 - 01.01.2015 01:00 (CET/CEST)
# 1  France (FR)  01.01.2015 01:00 - 01.01.2015 02:00 (CET/CEST)
# 2  France (FR)  01.01.2015 02:00 - 01.01.2015 03:00 (CET/CEST)
# 3  France (FR)  01.01.2015 03:00 - 01.01.2015 04:00 (CET/CEST)
# 4  France (FR)  01.01.2015 04:00 - 01.01.2015 05:00 (CET/CEST)
#
#            DATETIME  YEAR  Biomass  - Actual Aggregated [MW]  \
# 0  01.01.2015 00:00  2015                              193.0
# 1  01.01.2015 01:00  2015                              193.0
# 2  01.01.2015 02:00  2015                              193.0
# 3  01.01.2015 03:00  2015                              193.0
# 4  01.01.2015 04:00  2015                              193.0
#
#   Fossil Brown coal/Lignite  - Actual Aggregated [MW]  \
# 0                                                n/e
# 1                                                n/e
# ...

# %%
# Check data types
print(df.dtypes)
# Out:
# Area                                                          object
# MTU                                                           object
# DATETIME                                                      object
# YEAR                                                           int64
# Biomass  - Actual Aggregated [MW]                            float64
# Fossil Brown coal/Lignite  - Actual Aggregated [MW]           object
# Fossil Coal-derived gas  - Actual Aggregated [MW]             object
# Fossil Gas  - Actual Aggregated [MW]                         float64
# Fossil Hard coal  - Actual Aggregated [MW]                   float64
# Fossil Oil  - Actual Aggregated [MW]                         float64
# Fossil Oil shale  - Actual Aggregated [MW]                    object
# Fossil Peat  - Actual Aggregated [MW]                         object
# Geothermal  - Actual Aggregated [MW]                          object
# Hydro Pumped Storage  - Actual Aggregated [MW]               float64
# ...

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# Area                                                             0
# MTU                                                              0
# DATETIME                                                         0
# YEAR                                                             0
# Biomass  - Actual Aggregated [MW]                               80
# Fossil Brown coal/Lignite  - Actual Aggregated [MW]              8
# Fossil Coal-derived gas  - Actual Aggregated [MW]                8
# Fossil Gas  - Actual Aggregated [MW]                            81
# Fossil Hard coal  - Actual Aggregated [MW]                    3995
# Fossil Oil  - Actual Aggregated [MW]                            82
# Fossil Oil shale  - Actual Aggregated [MW]                       8
# Fossil Peat  - Actual Aggregated [MW]                            8
# Geothermal  - Actual Aggregated [MW]                             8
# Hydro Pumped Storage  - Actual Aggregated [MW]               29957
# ...

# %%
# Basic statistics for numerical columns
print(df.describe())
# Out:
#                YEAR  Biomass  - Actual Aggregated [MW]  \
# count  67831.000000                       67751.000000
# mean    2018.380711                         335.920311
# std        2.235456                          93.658593
# min     2015.000000                         104.000000
# 25%     2016.000000                         286.000000
# 50%     2018.000000                         322.000000
# 75%     2020.000000                         353.000000
# max     2022.000000                        1149.000000
#
#        Fossil Gas  - Actual Aggregated [MW]  \
# count                          67750.000000
# mean                            3895.820738
# std                             2431.711101
# min                              300.000000
# 25%                             1889.000000
# 50%                             3570.000000
# 75%                             5699.000000
# max                            25289.000000
#
#        Fossil Hard coal  - Actual Aggregated [MW]  \
# ...

# %% [markdown]
# ## Italy Exploration Data

# %%
df = pd.read_csv("/workspace/Renewable-Energy-Prediction/data/raw/Italy_Power_Generation.csv")

# %%
# Basic information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59070 entries, 0 to 59069
# Data columns (total 25 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Area                                                       59070 non-null  object
#  1   MTU                                                        59070 non-null  object
#  2   DATETIME                                                   59070 non-null  object
#  3   YEAR                                                       59070 non-null  int64
#  4   Biomass  - Actual Aggregated [MW]                          59047 non-null  float64
#  5   Fossil Brown coal/Lignite  - Actual Aggregated [MW]        59063 non-null  object
#  6   Fossil Coal-derived gas  - Actual Aggregated [MW]          58495 non-null  float64
# ...

# %%
# Display the first few rows to understand the structure
print(df.head())
# Out:
#          Area                                             MTU  \
# 0  Italy (IT)  01.01.2016 00:00 - 01.01.2016 01:00 (CET/CEST)
# 1  Italy (IT)  01.01.2016 01:00 - 01.01.2016 02:00 (CET/CEST)
# 2  Italy (IT)  01.01.2016 02:00 - 01.01.2016 03:00 (CET/CEST)
# 3  Italy (IT)  01.01.2016 03:00 - 01.01.2016 04:00 (CET/CEST)
# 4  Italy (IT)  01.01.2016 04:00 - 01.01.2016 05:00 (CET/CEST)
#
#            DATETIME  YEAR  Biomass  - Actual Aggregated [MW]  \
# 0  01.01.2016 00:00  2016                              220.0
# 1  01.01.2016 01:00  2016                              216.0
# 2  01.01.2016 02:00  2016                              217.0
# 3  01.01.2016 03:00  2016                              216.0
# 4  01.01.2016 04:00  2016                              215.0
#
#   Fossil Brown coal/Lignite  - Actual Aggregated [MW]  \
# 0                                                n/e
# 1                                                n/e
# 2                                                n/e
# ...

# %%
# Check data types
print(df.dtypes)
# Out:
# Area                                                          object
# MTU                                                           object
# DATETIME                                                      object
# YEAR                                                           int64
# Biomass  - Actual Aggregated [MW]                            float64
# Fossil Brown coal/Lignite  - Actual Aggregated [MW]           object
# Fossil Coal-derived gas  - Actual Aggregated [MW]            float64
# Fossil Gas  - Actual Aggregated [MW]                         float64
# Fossil Hard coal  - Actual Aggregated [MW]                   float64
# Fossil Oil  - Actual Aggregated [MW]                         float64
# Fossil Oil shale  - Actual Aggregated [MW]                    object
# Fossil Peat  - Actual Aggregated [MW]                         object
# Geothermal  - Actual Aggregated [MW]                         float64
# Hydro Pumped Storage  - Actual Aggregated [MW]               float64
# ...

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# Area                                                             0
# MTU                                                              0
# DATETIME                                                         0
# YEAR                                                             0
# Biomass  - Actual Aggregated [MW]                               23
# Fossil Brown coal/Lignite  - Actual Aggregated [MW]              7
# Fossil Coal-derived gas  - Actual Aggregated [MW]              575
# Fossil Gas  - Actual Aggregated [MW]                            23
# Fossil Hard coal  - Actual Aggregated [MW]                     119
# Fossil Oil  - Actual Aggregated [MW]                            23
# Fossil Oil shale  - Actual Aggregated [MW]                       7
# Fossil Peat  - Actual Aggregated [MW]                            7
# Geothermal  - Actual Aggregated [MW]                            23
# Hydro Pumped Storage  - Actual Aggregated [MW]                1507
# ...

# %%
# Basic statistics for numerical columns
print(df.describe())
# Out:
#                YEAR  Biomass  - Actual Aggregated [MW]  \
# count  59070.000000                       59047.000000
# mean    2018.882123                         503.847901
# std        1.947274                         161.482369
# min     2016.000000                         167.000000
# 25%     2017.000000                         354.000000
# 50%     2019.000000                         534.000000
# 75%     2021.000000                         651.000000
# max     2022.000000                         845.000000
#
#        Fossil Coal-derived gas  - Actual Aggregated [MW]  \
# count                                       58495.000000
# mean                                          439.063971
# std                                           246.285346
# min                                             0.000000
# 25%                                           235.000000
# 50%                                           396.000000
# 75%                                           620.000000
# ...

# %% [markdown]
# ## Spain Exploration Data

# %%
df = pd.read_csv("/workspace/Renewable-Energy-Prediction/data/raw/Spain_Power_Generation.csv")

# %%
# Basic information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76969 entries, 0 to 76968
# Data columns (total 25 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Area                                                       76969 non-null  object
#  1   MTU                                                        76969 non-null  object
#  2   DATETIME                                                   76969 non-null  object
#  3   YEAR                                                       76969 non-null  int64
#  4   Biomass  - Actual Aggregated [MW]                          76906 non-null  float64
#  5   Fossil Brown coal/Lignite  - Actual Aggregated [MW]        76905 non-null  float64
#  6   Fossil Coal-derived gas  - Actual Aggregated [MW]          76906 non-null  float64
# ...

# %%
# Display the first few rows to understand the structure
print(df.head())
# Out:
#          Area                                             MTU  \
# 0  Spain (ES)  01.01.2015 00:00 - 01.01.2015 01:00 (CET/CEST)
# 1  Spain (ES)  01.01.2015 01:00 - 01.01.2015 02:00 (CET/CEST)
# 2  Spain (ES)  01.01.2015 02:00 - 01.01.2015 03:00 (CET/CEST)
# 3  Spain (ES)  01.01.2015 03:00 - 01.01.2015 04:00 (CET/CEST)
# 4  Spain (ES)  01.01.2015 04:00 - 01.01.2015 05:00 (CET/CEST)
#
#            DATETIME  YEAR  Biomass  - Actual Aggregated [MW]  \
# 0  01.01.2015 00:00  2015                              447.0
# 1  01.01.2015 01:00  2015                              449.0
# 2  01.01.2015 02:00  2015                              448.0
# 3  01.01.2015 03:00  2015                              438.0
# 4  01.01.2015 04:00  2015                              428.0
#
#    Fossil Brown coal/Lignite  - Actual Aggregated [MW]  \
# 0                                              329.0
# 1                                              328.0
# 2                                              323.0
# ...

# %%
# Check data types
print(df.dtypes)
# Out:
# Area                                                          object
# MTU                                                           object
# DATETIME                                                      object
# YEAR                                                           int64
# Biomass  - Actual Aggregated [MW]                            float64
# Fossil Brown coal/Lignite  - Actual Aggregated [MW]          float64
# Fossil Coal-derived gas  - Actual Aggregated [MW]            float64
# Fossil Gas  - Actual Aggregated [MW]                         float64
# Fossil Hard coal  - Actual Aggregated [MW]                   float64
# Fossil Oil  - Actual Aggregated [MW]                         float64
# Fossil Oil shale  - Actual Aggregated [MW]                   float64
# Fossil Peat  - Actual Aggregated [MW]                        float64
# Geothermal  - Actual Aggregated [MW]                         float64
# Hydro Pumped Storage  - Actual Aggregated [MW]               float64
# ...

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# Area                                                             0
# MTU                                                              0
# DATETIME                                                         0
# YEAR                                                             0
# Biomass  - Actual Aggregated [MW]                               63
# Fossil Brown coal/Lignite  - Actual Aggregated [MW]             64
# Fossil Coal-derived gas  - Actual Aggregated [MW]               63
# Fossil Gas  - Actual Aggregated [MW]                            62
# Fossil Hard coal  - Actual Aggregated [MW]                      63
# Fossil Oil  - Actual Aggregated [MW]                            65
# Fossil Oil shale  - Actual Aggregated [MW]                      62
# Fossil Peat  - Actual Aggregated [MW]                           63
# Geothermal  - Actual Aggregated [MW]                            63
# Hydro Pumped Storage  - Actual Aggregated [MW]               76969
# ...

# %%
# Basic statistics for numerical columns
print(df.describe())
# Out:
#                YEAR  Biomass  - Actual Aggregated [MW]  \
# count  76969.000000                       76906.000000
# mean    2018.810404                         412.978051
# std        2.403026                          86.916096
# min     2015.000000                           0.000000
# 25%     2017.000000                         351.000000
# 50%     2019.000000                         400.000000
# 75%     2021.000000                         487.000000
# max     2022.000000                         609.000000
#
#        Fossil Brown coal/Lignite  - Actual Aggregated [MW]  \
# count                                       76905.000000
# mean                                          210.971471
# std                                           328.973514
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                           454.000000
# ...

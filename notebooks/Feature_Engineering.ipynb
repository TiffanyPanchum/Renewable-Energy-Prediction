# %%
# Feature Engineering Pipeline
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import joblib

# %%
# Load cleaned dataset
df = pd.read_csv('/workspace/Renewable-Energy-Prediction/data/processed/Merged_Dataset/final_combined_dataset.csv', parse_dates=['time'])
